# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
import pandas as pd

# importing scikit learn with make_blobs 
from sklearn.datasets.samples_generator import make_blobs
  
# creating datasets X containing n_samples 
# Y containing two classes 
X, Y = make_blobs(n_samples=1000, centers=3, 
                  random_state=0, cluster_std=0.40) 
# plotting scatters  
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring'); 
plt.show()

# creating line space between -1 to 3.5  
xfit = np.linspace(-1, 3.5) 
  
# plotting scatter 
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring')

# plot a line between the different sets of data 
for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-1, 3.5)
plt.show()

# %%
# import numpy as np 
# import pandas as pd 
# import matplotlib.pyplot as plt
# import pandas as pd
# url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
# colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
# irisdata = pd.read_csv(url, names=colnames)
# X, Y = irisdata(n_samples=500, centers=2,random_state=0, cluster_std=0.40)  
# plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring'); 
# plt.show()
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Assign colum names to the dataset
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# Read dataset to pandas dataframe
irisdata = pd.read_csv(url, names=colnames)
V = np.array(irisdata)
X = irisdata.drop('Class', axis=1)
y = irisdata['Class']

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], s=50, cmap='spring'); 
plt.show()

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# from sklearn.svm import SVC
# svclassifier = SVC(kernel='poly', degree=8)
# #svclassifier = SVC(kernel='linear')
# svclassifier.fit(X_train, y_train)

# y_pred = svclassifier.predict(X_test)

# from sklearn.metrics import classification_report, confusion_matrix
# print(confusion_matrix(y_test, y_pred))
# print(classification_report(y_test, y_pred))

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas as pd
billdata = pd.read_csv("Bill.csv")
X = billdata.drop('Class', axis=1)
Y = billdata['Class']
X_one = np.array(X)
Y_one = np.array(Y)
print(X_one)
plt.scatter(X_one[:, 1], X_one[:, 2], c=Y_one[:], s=20, cmap='spring')
plt.show()
xfit = np.linspace(-7, 7) 
plt.scatter(X_one[:, 0], X_one[:, 1], c=Y_one, s=20, cmap='spring')
for m, b, d in [(-0.7, 5.65, 0.33), (-0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-7, 7)
plt.show()
# Out:
# [[  3.6216    8.6661   -2.8073   -0.44699]
#  [  4.5459    8.1674   -2.4586   -1.4621 ]
#  [  3.866    -2.6383    1.9242    0.10645]
#  ...
#  [ -3.7503  -13.4586   17.5932   -2.7771 ]
#  [ -3.5637   -8.3827   12.393    -1.2823 ]
#  [ -2.5419   -0.65804   2.6842    1.1952 ]]

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
billdata = pd.read_csv("Bill.csv")
X = billdata.drop('Class', axis=1)
Y = billdata['Class']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30)
X_one = np.array(X_train)
Y_one = np.array(y_train)

# %%
plt.scatter(X_one[:500, 0], X_one[:500, 1], c=Y_one[:500], s=20, cmap='spring')
plt.show()
xfit = np.linspace(-7, 10) 
plt.scatter(X_one[:500, 0], X_one[:500, 1], c=Y_one[:500], s=20, cmap='spring')
for m, b, d in [(-0.1, -1.65, 0.33),(-1.1,-1.65,0.33), (-2.1,-1.65,0.33)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-7, 10)
plt.show()

# %%
plt.scatter(X_one[:500, 0], X_one[:500, 1], c=Y_one[:500], s=20, cmap='spring')
plt.show()
xfit = np.linspace(-7, 10) 
plt.scatter(X_one[:500, 0], X_one[:500, 1], c=Y_one[:500], s=20, cmap='spring')
for m, b, d in [(-0.1, -1.65, 0.33),(-1.1,-2.65,0.33), (-2.1,-3.65,0.33)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-7, 10)
plt.show()

# %%
plt.scatter(X_one[:500, 0], X_one[:500, 1], c=Y_one[:500], s=20, cmap='spring')
plt.show()
xfit = np.linspace(-7, 10) 
plt.scatter(X_one[:500, 0], X_one[:500, 1], c=Y_one[:500], s=20, cmap='spring')
for m, b, d in [(-2.1, -1.65, 0.33),(-2.1,-4.65,0.33), (-2.1,3.65,0.33)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-7, 10)
plt.show()

# %%
from libsvm import *
from sklearn import svm
from sklearn.svm import svm_problem
prob = svm_problem([1,-1],[[1,0,1],[-1,0,-1]])
param = svm_parameter(kernel_type = LINEAR, C = 10)
  ## training  the model
m = svm_model(prob, param)
#testing the model
m.predict([1, 1, 1])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-2a0f1ab91a06> in <module>
#       1 from libsvm import *
#       2 from sklearn import svm
# ----> 3 from sklearn.svm import svm_problem
#       4 prob = svm_problem([1,-1],[[1,0,1],[-1,0,-1]])
#       5 param = svm_parameter(kernel_type = LINEAR, C = 10)
#
# ImportError: cannot import name 'svm_problem' from 'sklearn.svm' (D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\svm\__init__.py)

# %%
from svm import svm_problem
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-25cd1d43f081> in <module>
# ----> 1 from svm import svm_problem
#
# ImportError: cannot import name 'svm_problem' from 'svm' (D:\User\Ambarish\Anaconda_i\lib\site-packages\svm\__init__.py)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

billdata = pd.read_csv("Bill.csv")
X = billdata.drop('Class', axis=1)
Y = billdata['Class']
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.30)

# %%
svclassifier = SVC(kernel='linear', C=50)
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)

# %%
svclassifier = SVC(kernel='rbf')
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[49  3]
#  [ 2 46]]
#               precision    recall  f1-score   support
#
#            8       0.96      0.94      0.95        52
#            9       0.94      0.96      0.95        48
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
# rmse= 0.22360679774997896

# %%
svclassifier = SVC(kernel='sigmoid')
svclassifier.fit(X_train, y_train)
y_pred = svclassifier.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[45  7]
#  [ 6 42]]
#               precision    recall  f1-score   support
#
#            8       0.88      0.87      0.87        52
#            9       0.86      0.88      0.87        48
#
#     accuracy                           0.87       100
#    macro avg       0.87      0.87      0.87       100
# weighted avg       0.87      0.87      0.87       100
#
# rmse= 0.36055512754639896

# %%
data = pd.read_csv("Data_Train.csv")
newdata = data[data.iloc[:,25].values > 7]
X = newdata.iloc[:, 0:24].values
y = newdata.iloc[:, 25].values
print(len(y))
# print(y)
# print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
# Out:
# 1937

# %%
svc=svm.SVC(kernel='linear',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# rmse= 0.2212895663264503

# %%
svc=svm.SVC(kernel='linear',C=1,gamma=10).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[207  11]
#  [  8 162]]
#               precision    recall  f1-score   support
#
#            8       0.96      0.95      0.96       218
#            9       0.94      0.95      0.94       170
#
#     accuracy                           0.95       388
#    macro avg       0.95      0.95      0.95       388
# weighted avg       0.95      0.95      0.95       388

# %%
X = newdata.iloc[:500, 0:24].values
y = newdata.iloc[:500, 25].values
# print(y)
# print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
svc=svm.SVC(kernel='linear',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [ 3 51]]
#               precision    recall  f1-score   support
#
#            8       0.94      1.00      0.97        46
#            9       1.00      0.94      0.97        54
#
#     accuracy                           0.97       100
#    macro avg       0.97      0.97      0.97       100
# weighted avg       0.97      0.97      0.97       100
#
# rmse= 0.17320508075688773

# %%
svc=svm.SVC(kernel='linear',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [ 3 51]]
#               precision    recall  f1-score   support
#
#            8       0.94      1.00      0.97        46
#            9       1.00      0.94      0.97        54
#
#     accuracy                           0.97       100
#    macro avg       0.97      0.97      0.97       100
# weighted avg       0.97      0.97      0.97       100
#
# rmse= 0.17320508075688773

# %%
svc=svm.SVC(kernel='linear',C=4,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [ 2 52]]
#               precision    recall  f1-score   support
#
#            8       0.96      1.00      0.98        46
#            9       1.00      0.96      0.98        54
#
#     accuracy                           0.98       100
#    macro avg       0.98      0.98      0.98       100
# weighted avg       0.98      0.98      0.98       100
#
# rmse= 0.1414213562373095

# %%
svc=svm.SVC(kernel='poly',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [ 1 53]]
#               precision    recall  f1-score   support
#
#            8       0.98      1.00      0.99        46
#            9       1.00      0.98      0.99        54
#
#     accuracy                           0.99       100
#    macro avg       0.99      0.99      0.99       100
# weighted avg       0.99      0.99      0.99       100
#
# rmse= 0.1

# %%
svc=svm.SVC(kernel='poly',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [ 1 53]]
#               precision    recall  f1-score   support
#
#            8       0.98      1.00      0.99        46
#            9       1.00      0.98      0.99        54
#
#     accuracy                           0.99       100
#    macro avg       0.99      0.99      0.99       100
# weighted avg       0.99      0.99      0.99       100
#
# rmse= 0.1

# %%
svc=svm.SVC(kernel='poly',C=4,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [ 1 53]]
#               precision    recall  f1-score   support
#
#            8       0.98      1.00      0.99        46
#            9       1.00      0.98      0.99        54
#
#     accuracy                           0.99       100
#    macro avg       0.99      0.99      0.99       100
# weighted avg       0.99      0.99      0.99       100
#
# rmse= 0.1

# %%
svc=svm.SVC(kernel='rbf',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [54  0]]
#               precision    recall  f1-score   support
#
#            8       0.46      1.00      0.63        46
#            9       0.00      0.00      0.00        54
#
#     accuracy                           0.46       100
#    macro avg       0.23      0.50      0.32       100
# weighted avg       0.21      0.46      0.29       100
#
# rmse= 0.7348469228349535
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='rbf',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [54  0]]
#               precision    recall  f1-score   support
#
#            8       0.46      1.00      0.63        46
#            9       0.00      0.00      0.00        54
#
#     accuracy                           0.46       100
#    macro avg       0.23      0.50      0.32       100
# weighted avg       0.21      0.46      0.29       100
#
# rmse= 0.7348469228349535
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='rbf',C=4,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [54  0]]
#               precision    recall  f1-score   support
#
#            8       0.46      1.00      0.63        46
#            9       0.00      0.00      0.00        54
#
#     accuracy                           0.46       100
#    macro avg       0.23      0.50      0.32       100
# weighted avg       0.21      0.46      0.29       100
#
# rmse= 0.7348469228349535
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='rbf',C=100,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  0]
#  [54  0]]
#               precision    recall  f1-score   support
#
#            8       0.46      1.00      0.63        46
#            9       0.00      0.00      0.00        54
#
#     accuracy                           0.46       100
#    macro avg       0.23      0.50      0.32       100
# weighted avg       0.21      0.46      0.29       100
#
# rmse= 0.7348469228349535
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='sigmoid',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[41  5]
#  [16 38]]
#               precision    recall  f1-score   support
#
#            8       0.72      0.89      0.80        46
#            9       0.88      0.70      0.78        54
#
#     accuracy                           0.79       100
#    macro avg       0.80      0.80      0.79       100
# weighted avg       0.81      0.79      0.79       100
#
# rmse= 0.458257569495584

# %%
svc=svm.SVC(kernel='sigmoid',C=1,gamma=10).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[41  5]
#  [16 38]]
#               precision    recall  f1-score   support
#
#            8       0.72      0.89      0.80        46
#            9       0.88      0.70      0.78        54
#
#     accuracy                           0.79       100
#    macro avg       0.80      0.80      0.79       100
# weighted avg       0.81      0.79      0.79       100
#
# rmse= 0.458257569495584

# %%
svc=svm.SVC(kernel='sigmoid',C=4,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[40  6]
#  [15 39]]
#               precision    recall  f1-score   support
#
#            8       0.73      0.87      0.79        46
#            9       0.87      0.72      0.79        54
#
#     accuracy                           0.79       100
#    macro avg       0.80      0.80      0.79       100
# weighted avg       0.80      0.79      0.79       100
#
# rmse= 0.458257569495584

# %%
X = newdata.iloc[:500, 0:10].values
y = newdata.iloc[:500, 25].values
# print(y)
# print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
svc=svm.SVC(kernel='linear',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  6]
#  [ 5 43]]
#               precision    recall  f1-score   support
#
#            8       0.90      0.88      0.89        52
#            9       0.88      0.90      0.89        48
#
#     accuracy                           0.89       100
#    macro avg       0.89      0.89      0.89       100
# weighted avg       0.89      0.89      0.89       100
#
# rmse= 0.33166247903553997

# %%
svc=svm.SVC(kernel='linear',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  6]
#  [ 5 43]]
#               precision    recall  f1-score   support
#
#            8       0.90      0.88      0.89        52
#            9       0.88      0.90      0.89        48
#
#     accuracy                           0.89       100
#    macro avg       0.89      0.89      0.89       100
# weighted avg       0.89      0.89      0.89       100
#
# rmse= 0.33166247903553997

# %%
svc=svm.SVC(kernel='linear',C=10,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[46  6]
#  [ 5 43]]
#               precision    recall  f1-score   support
#
#            8       0.90      0.88      0.89        52
#            9       0.88      0.90      0.89        48
#
#     accuracy                           0.89       100
#    macro avg       0.89      0.89      0.89       100
# weighted avg       0.89      0.89      0.89       100
#
# rmse= 0.33166247903553997

# %%
svc=svm.SVC(kernel='poly',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[51  1]
#  [ 4 44]]
#               precision    recall  f1-score   support
#
#            8       0.93      0.98      0.95        52
#            9       0.98      0.92      0.95        48
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
# rmse= 0.22360679774997896

# %%
svc=svm.SVC(kernel='poly',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[51  1]
#  [ 4 44]]
#               precision    recall  f1-score   support
#
#            8       0.93      0.98      0.95        52
#            9       0.98      0.92      0.95        48
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
# rmse= 0.22360679774997896

# %%
svc=svm.SVC(kernel='poly',C=10,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[51  1]
#  [ 4 44]]
#               precision    recall  f1-score   support
#
#            8       0.93      0.98      0.95        52
#            9       0.98      0.92      0.95        48
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
# rmse= 0.22360679774997896

# %%
svc=svm.SVC(kernel='rbf',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[ 0 52]
#  [ 0 48]]
#               precision    recall  f1-score   support
#
#            8       0.00      0.00      0.00        52
#            9       0.48      1.00      0.65        48
#
#     accuracy                           0.48       100
#    macro avg       0.24      0.50      0.32       100
# weighted avg       0.23      0.48      0.31       100
#
# rmse= 0.7211102550927979
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='rbf',C=4,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[ 0 52]
#  [ 0 48]]
#               precision    recall  f1-score   support
#
#            8       0.00      0.00      0.00        52
#            9       0.48      1.00      0.65        48
#
#     accuracy                           0.48       100
#    macro avg       0.24      0.50      0.32       100
# weighted avg       0.23      0.48      0.31       100
#
# rmse= 0.7211102550927979
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='rbf',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[ 0 52]
#  [ 0 48]]
#               precision    recall  f1-score   support
#
#            8       0.00      0.00      0.00        52
#            9       0.48      1.00      0.65        48
#
#     accuracy                           0.48       100
#    macro avg       0.24      0.50      0.32       100
# weighted avg       0.23      0.48      0.31       100
#
# rmse= 0.7211102550927979
# D:\User\Ambarish\Anaconda_i\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
svc=svm.SVC(kernel='sigmoid',C=1,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[39 13]
#  [16 32]]
#               precision    recall  f1-score   support
#
#            8       0.71      0.75      0.73        52
#            9       0.71      0.67      0.69        48
#
#     accuracy                           0.71       100
#    macro avg       0.71      0.71      0.71       100
# weighted avg       0.71      0.71      0.71       100
#
# rmse= 0.5385164807134504

# %%
svc=svm.SVC(kernel='sigmoid',C=1,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[39 13]
#  [16 32]]
#               precision    recall  f1-score   support
#
#            8       0.71      0.75      0.73        52
#            9       0.71      0.67      0.69        48
#
#     accuracy                           0.71       100
#    macro avg       0.71      0.71      0.71       100
# weighted avg       0.71      0.71      0.71       100
#
# rmse= 0.5385164807134504

# %%
svc=svm.SVC(kernel='sigmoid',C=10,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[41 11]
#  [14 34]]
#               precision    recall  f1-score   support
#
#            8       0.75      0.79      0.77        52
#            9       0.76      0.71      0.73        48
#
#     accuracy                           0.75       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.75      0.75      0.75       100
#
# rmse= 0.5

# %%
svc=svm.SVC(kernel='sigmoid',C=4,gamma=100).fit(X_train,y_train)
y_pred = svc.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[41 11]
#  [14 34]]
#               precision    recall  f1-score   support
#
#            8       0.75      0.79      0.77        52
#            9       0.76      0.71      0.73        48
#
#     accuracy                           0.75       100
#    macro avg       0.75      0.75      0.75       100
# weighted avg       0.75      0.75      0.75       100
#
# rmse= 0.5
