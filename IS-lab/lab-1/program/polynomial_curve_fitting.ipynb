# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 18 15:52:56 2020

@author: Adhyyan
"""
# from sklearn import model_selection
# from sklearn import svm
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import random

# data =pd.read_csv('Training_Dataset.csv')
# n=random.randint(0,10000)
# print(n)
# arr=np.arrange(20*25).reshape(20,25)
# X=data.iloc[:,0:25].values
# y=data.iloc[:,25].values

# plt.scatter(X, y, color='blue')
# plt.xlabel("Predictor", fontsize=16)
# plt.ylabel("Target", fontsize=16)
# plt.show()




import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler
import operator
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

dataset = pd.read_csv('Training_Dataset.csv')
n=random.randint(0,10000)
x = dataset.iloc[:, 0:25].values
y = dataset.iloc[:, 25].values
print(np.amax(x))
print(np.amin(x))
scaler = MinMaxScaler(feature_range=(-1,1))
                      
polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)
lm = LinearRegression()
lm.fit(x_poly, y)
y_poly_pred = lm.predict(x_poly)
plt.plot(x,y_poly_pred,color='red')

rmse = np.sqrt(mean_squared_error(y,y_poly_pred))
r2 = r2_score(y,y_poly_pred)

print(rmse)
print(r2)







# plt.scatter(np.array(x), y, s=10)
# # sort the values of x before line plot
# sort_axis = operator.itemgetter(0)
# sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
# x, y_poly_pred = zip(*sorted_zip)
# plt.plot(x, y_poly_pred, color='m')
# plt.show()
# Out:
# 2342.543549
# -1461.695218
# 0.6782103850952251
# 0.9456088266223602

# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Aug 18 15:52:56 2020

@author: Adhyyan
"""
# from sklearn import model_selection
# from sklearn import svm
# import numpy as np
# import matplotlib.pyplot as plt
# import pandas as pd
# import random

# data =pd.read_csv('Training_Dataset.csv')
# n=random.randint(0,10000)
# print(n)
# arr=np.arrange(20*25).reshape(20,25)
# X=data.iloc[:,0:25].values
# y=data.iloc[:,25].values

# plt.scatter(X, y, color='blue')
# plt.xlabel("Predictor", fontsize=16)
# plt.ylabel("Target", fontsize=16)
# plt.show()


from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler
import operator
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures

dataset = pd.read_csv('Training_Dataset.csv')
n=random.randint(0,10000)
x = dataset.iloc[:, 24:25].values
y = dataset.iloc[:, 25].values




polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)
# print(x_train)
# print(y_train)
# print(x_test)
print("Wait....")
# print(y_test)
lm = LinearRegression()
lm.fit(x_poly, y)

dataset_test = pd.read_csv('Test_Dataset.csv')
x_test=dataset_test.iloc[:,0:17]
y_test=dataset_test.iloc[:,17]

x_poly_test = polynomial_features.fit_transform(x_test)
y_poly_pred = lm.predict(x_poly_test)

plt.plot(x_poly_test,y_poly_pred,color='red')
print(lm.score(x_poly_test,y_poly_pred))

rmse = np.sqrt(mean_squared_error(y_test,y_poly_pred))
r2 = r2_score(y_test,y_poly_pred)

print(rmse)
print(r2)







# plt.scatter(np.array(x), y, s=10)
# # sort the values of x before line plot
# sort_axis = operator.itemgetter(0)
# sorted_zip = sorted(zip(x,y_poly_pred), key=sort_axis)
# x, y_poly_pred = zip(*sorted_zip)
# plt.plot(x, y_poly_pred, color='m')
# plt.show()
# Out:
# Wait....
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-103-d9171eebdf1c> in <module>
#      59
#      60 x_poly_test = polynomial_features.fit_transform(x_test)
# ---> 61 y_poly_pred = lm.predict(x_poly_test)
#      62
#      63 plt.plot(x_poly_test,y_poly_pred,color='red')
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
#     211     def predict(self, X):
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 4 is different from 1140)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler
import operator
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures


dataset = pd.read_csv('Training_Dataset.csv')
n=random.randint(0,9980)
x = dataset.iloc[:, 0:25].values
y = dataset.iloc[:, 25].values

deg=[]
err=[]
for i in range(1,6):
    poly_feat=PolynomialFeatures(degree=i)
    x_poly=poly_feat.fit_transform(x)
    lm=LinearRegression()
    lm.fit(x_poly,y)
    y_pred=lm.predict(x_poly)
    print("For Degree ",i,end=" ")
    #plt.plot(x,y_pred,color='red')
    rmse = np.sqrt(mean_squared_error(y,y_pred))
    r2 = r2_score(y,y_pred)
    print("RMSE= ",rmse,end=" ")
    print("r2=",r2)
    deg.append(i)
    err.append(rmse)

plt.xlabel("RMSE", fontsize=16)
plt.ylabel("Degree", fontsize=16)
plt.plot(err,deg)
# print(rmse)
# print(r2)
# plt.show()
# Out:
# For Degree  1 RMSE=  2.0386141598645158 r2= 0.508560987638887
# For Degree  2 RMSE=  1.2516318629281786 r2= 0.8147523200056312
# For Degree  3 RMSE=  0.6782103850952251 r2= 0.9456088266223602

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression, Ridge, Lasso 
from sklearn.model_selection import train_test_split, cross_val_score 
from statistics import mean 
import random
from sklearn.preprocessing import PolynomialFeatures

dataset = pd.read_csv('Training_Dataset.csv')
n=random.randint(0,9980)
x = dataset.iloc[n:n+20, 0:25].values
y = dataset.iloc[n:n+20, 25].values

polynomial_features= PolynomialFeatures(degree=3)
x_poly = polynomial_features.fit_transform(x)
X_train, X_test, y_train, y_test = train_test_split(x_poly, y, test_size = 0.2) 
lm = LinearRegression()
lm.fit(X_train, y_train)
# y_poly_pred = lm.predict(x_poly)
print(lm.score(X_test,y_test))

# ridgeModelChosen = Ridge(alpha = 0.25) 
# ridgeModelChosen.fit(X_train, y_train) 
  
# Evaluating the Ridge Regression model 
# print(ridgeModelChosen.score(X_test, y_test)) 

cross_val_scores_ridge = [] 
  
# List to maintain the different values of alpha 
alpha = [] 
le=0
# Loop to compute the different values of cross-validation scores 
for i in range(1, 10000): 
    ridgeModel = Ridge(alpha = i * 0.25) 
    ridgeModel.fit(X_train, y_train) 
    scores = cross_val_score(ridgeModel, x, y, cv = 10) 
    avg_cross_val_score = mean(scores)*100
    cross_val_scores_ridge.append(avg_cross_val_score) 
    alpha.append(i * 0.25) 
  
maxi=0
# Loop to print the different values of cross-validation scores 
for i in range(0, len(alpha)):
    if (cross_val_scores_ridge[i]<le):
        le=cross_val_scores_ridge[i]
        maxi=alpha[i]
        
#     print(str(alpha[i])+' : '+str(cross_val_scores_ridge[i])) 
print(le)
print(maxi)
# Out:
# 0.15735562836854844
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=6.12726e-18): result may not be accurate.
#   overwrite_a=False)
# ...
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.39361e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# -498.79542144368224
# 0.25
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=5.41779e-17): result may not be accurate.
#   overwrite_a=False)

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from sklearn.preprocessing import MinMaxScaler
import operator
from sklearn.linear_model import LinearRegression,Ridge
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures


dataset = pd.read_csv('Training_Dataset.csv')
n=random.randint(0,9980)
x = dataset.iloc[n:n+20, 0:25].values
y = dataset.iloc[n:n+20, 25].values

deg=[]
err=[]
for i in range(1,5):
    poly_feat=PolynomialFeatures(degree=i)
    x_poly=poly_feat.fit_transform(x)
    X_train, X_test, y_train, y_test = train_test_split(x_poly, y, test_size = 0.2) 
    lm=Ridge(alpha=0.25)
    lm.fit(X_train,y_train)
    y_pred=lm.predict(X_test)
    rmse = np.sqrt(mean_squared_error(y_test,y_pred))
    r2 = r2_score(y_test,y_pred)
    print("RMSE= ",rmse,end=" ")
    print("r2=",r2)
    deg.append(i)
    err.append(r2)
    
plt.xlabel("R2", fontsize=16)
plt.ylabel("Degree", fontsize=16)
plt.plot(err,deg)
plt.show()
# Out:
# RMSE=  2.0129909749783406 r2= 0.5098981381251297
# RMSE=  1.317377480822378 r2= 0.7920267561268236
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=2.50758e-17): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:148: LinAlgWarning: Ill-conditioned matrix (rcond=5.48123e-24): result may not be accurate.
#   overwrite_a=True).T
# RMSE=  1.334748399030543 r2= 0.7914053692672142
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:188: LinAlgWarning: Ill-conditioned matrix (rcond=2.11455e-20): result may not be accurate.
#   overwrite_a=False)
# RMSE=  2.3707904506463104 r2= 0.3406484543490814
