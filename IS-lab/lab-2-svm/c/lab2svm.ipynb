# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
import pandas as pd

# importing scikit learn with make_blobs 
from sklearn.datasets.samples_generator import make_blobs 
  
# creating datasets X containing n_samples 
# Y containing two classes 
X, Y = make_blobs(n_samples=500,  centers=3,
                  random_state=0, cluster_std=0.40) 
# plotting scatters  
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring'); 
plt.show()

# creating line space between -1 to 3.5  
xfit = np.linspace(-1, 3.5) 
  
# plotting scatter 
plt.scatter(X[:, 0], X[:, 1], c=Y, s=50, cmap='spring')

# plot a line between the different sets of data 
for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-1, 3.5); 
plt.show()
# Out:
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC

url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"

# Assign colum names to the dataset
colnames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']

# Read dataset to pandas dataframe
irisdata = pd.read_csv(url, names=colnames)
V = np.array(irisdata)
X = irisdata.drop('Class', axis=1)
y = irisdata['Class']

plt.scatter(X.iloc[:, 0], X.iloc[:, 1], s=50); 
plt.show()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

from sklearn.svm import SVC
svclassifier = SVC(kernel='linear')
#svclassifier = SVC(kernel='linear')
svclassifier.fit(X_train, y_train)

y_pred = svclassifier.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 8  0  0]
#  [ 0  8  1]
#  [ 0  0 13]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      0.89      0.94         9
#  Iris-virginica       0.93      1.00      0.96        13
#
#        accuracy                           0.97        30
#       macro avg       0.98      0.96      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %%
# importing required libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
  
# reading csv file and extracting class column to y. 
#Data = pd.read_csv("Data_Train.csv",header=None)
Data = pd.read_csv("Bill.csv")
V = np.array(Data)
#X = Data[:,0:3]
#Y  = Data[:,4] # classes having 0 and 1 
X = Data.drop('Class', axis=1)
y = Data['Class']

# plotting scatters  
plt.scatter(V[:, 0], V[:, 1], c=y, s=50, cmap='spring'); 
plt.show()

# # creating line space between -1 to 3.5  
# xfit = np.linspace(-1, 2.5) 
  
# # plotting scatter 
# plt.scatter(V[:, 0], V[:, 1], c=y, s=50, cmap='spring') 
  
# # plot a line between the different sets of data 
# for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
#     yfit = m * xfit + b 
#     plt.plot(xfit, yfit, '-k') 
#     plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
#     color='#AAAAAA', alpha=0.4) 
  
# plt.xlim(-1, 2.5); 
# plt.show() 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
#print (x),(y) 

 # "Support Vector Classifier" 
clf = SVC(kernel='sigmoid',C=1,gamma=1)

# fitting x samples and y classes 
clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
plt.plot(y_test,y_pred)
plt.show()
# Out:
# [[97 50]
#  [61 67]]
#               precision    recall  f1-score   support
#
#            0       0.61      0.66      0.64       147
#            1       0.57      0.52      0.55       128
#
#     accuracy                           0.60       275
#    macro avg       0.59      0.59      0.59       275
# weighted avg       0.59      0.60      0.59       275

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm, datasets
# import some data to play with
iris = pd.read_csv("Bill.csv")
X = Data.drop('Class', axis=1) # we only take the first two features. We could
# avoid this ugly slicing by using a two-dim dataset
y = Data['Class']
# we create an instance of SVM and fit out data. We do not scale our
# data since we want to plot the support vectors
C = 1.0 # SVM regularization parameter
svc = svm.SVC(kernel='rbf', C=1,gamma='auto').fit(X_train, y_train)
# create a mesh to plot in
x_min, x_max = X.iloc[:, 0].min() - 1, X.iloc[:, 0].max() + 1
y_min, y_max = X.iloc[:, 1].min() - 1, X.iloc[:, 1].max() + 1
h = (x_max / x_min)/100
xx, yy = np.meshgrid(np.arange(x_min, x_max, h),
np.arange(y_min, y_max, h))
plt.subplot(1, 1, 1)
Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
Z = Z.reshape(xx.shape)
plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=plt.cm.Paired)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.xlim(xx.min(), xx.max())
plt.title('SVC with linear kernel')
plt.show()

# from sklearn.metrics import classification_report, confusion_matrix
# # Z=Z.reshape(np.c_[xx.ravel(), yy.ravel()].shape)
# print(confusion_matrix(np.c_[xx.ravel(), yy.ravel()],Z))
# print(classification_report(np.c_[xx.ravel(), yy.ravel()],Z))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-2dbccdcf2c79> in <module>
#      18 np.arange(y_min, y_max, h))
#      19 plt.subplot(1, 1, 1)
# ---> 20 Z = svc.predict(np.c_[xx.ravel(), yy.ravel()])
#      21 Z = Z.reshape(xx.shape)
#      22 plt.contourf(xx, yy, Z, cmap=plt.cm.Paired, alpha=0.8)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     592             y = np.argmax(self.decision_function(X), axis=1)
#     593         else:
# --> 594             y = super().predict(X)
#     595         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     596
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     313         y_pred : array, shape (n_samples,)
#     314         """
# --> 315         X = self._validate_for_predict(X)
#     316         predict = self._sparse_predict if self._sparse else self._dense_predict
#     317         return predict(X)
#
# ~\anaconda3\lib\site-packages\sklearn\svm\_base.py in _validate_for_predict(self, X)
#     445
#     446         X = check_array(X, accept_sparse='csr', dtype=np.float64, order="C",
# --> 447                         accept_large_sparse=False)
#     448         if self._sparse and not sp.isspmatrix(X):
#     449             X = sp.csr_matrix(X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     584                              " minimum of %d is required%s."
#     585                              % (n_samples, array.shape, ensure_min_samples,
# --> 586                                 context))
#     587
#     588     if ensure_min_features > 0 and array.ndim == 2:
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required.

# %%
# importing required libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
  
# reading csv file and extracting class column to y. 
#Data = pd.read_csv("Data_Train.csv",header=None)
Data = pd.read_csv("Bill.csv")
V = np.array(Data)
#X = Data[:,0:3]
#Y  = Data[:,4] # classes having 0 and 1 
X = Data.drop('Class', axis=1)
y = Data['Class']

# plotting scatters  
plt.scatter(V[:, 0], V[:, 1], c=y, s=50, cmap='spring'); 
plt.show()

# creating line space between -1 to 3.5  
xfit = np.linspace(-1, 2.5) 
  
# plotting scatter 
plt.scatter(V[:, 0], V[:, 1], c=y, s=50, cmap='spring') 
  
# plot a line between the different sets of data 
for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-1, 2.5); 
plt.show() 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
#print (x),(y) 

 # "Support Vector Classifier" 
clf = SVC(kernel='rbf',C=1,gamma=1)

# fitting x samples and y classes 
clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-92554495f921> in <module>
#      23
#      24 # plotting scatter
# ---> 25 plt.scatter(V[:, 0], V[:, 1], c=r, s=50, cmap='spring')
#      26
#      27 # plot a line between the different sets of data
#
# NameError: name 'r' is not defined

# %%
# importing required libraries 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
  
# reading csv file and extracting class column to y. 
#Data = pd.read_csv("Data_Train.csv",header=None)
Data = pd.read_csv("Data_Train.csv")
new= Data[Data.iloc[:,25].values == 2 or Data.iloc[:,25].values == 6 ]
V = np.array(Data)
#X = Data[:,0:3]
#Y  = Data[:,4] # classes having 0 and 1 
X = Data.drop('Class', axis=1)
y = Data['Class']

# plotting scatters  
plt.scatter(V[:, 0], V[:, 1], c=y, s=50, cmap='spring'); 
plt.show()

# creating line space between -1 to 3.5  
xfit = np.linspace(-1, 2.5) 
  
# plotting scatter 
plt.scatter(V[:, 0], V[:, 1], c=y, s=50, cmap='spring') 
  
# plot a line between the different sets of data 
for m, b, d in [(1, 0.65, 0.33), (0.5, 1.6, 0.55), (-0.2, 2.9, 0.2)]: 
    yfit = m * xfit + b 
    plt.plot(xfit, yfit, '-k') 
    plt.fill_between(xfit, yfit - d, yfit + d, edgecolor='none',  
    color='#AAAAAA', alpha=0.4) 
  
plt.xlim(-1, 2.5); 
plt.show() 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
#print (x),(y) 

 # "Support Vector Classifier" 
clf = SVC(kernel='linear',C=1,gamma=1)

# fitting x samples and y classes 
clf.fit(X_train, y_train) 

y_pred = clf.predict(X_test)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-bed63f313eab> in <module>
#       9 #Data = pd.read_csv("Data_Train.csv",header=None)
#      10 Data = pd.read_csv("Data_Train.csv")
# ---> 11 new= Data[Data.iloc[:,25].values == 2 or Data.iloc[:,25].values == 6 ]
#      12 V = np.array(Data)
#      13 #X = Data[:,0:3]
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# Out:
# [6 6 6 ... 2 2 2]

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
import random 
Data = pd.read_csv("Data_Train.csv")

new= Data[(Data.iloc[:,25]==2) | (Data.iloc[:,25]==6)]
X = new.iloc[0:500, 0:25].values
# print(X)
y = new.iloc[0:500, 25].values
# print(len(y))
# print(y)
# print(y.shape)
X_train, X_test, y_train, y_test = train_test_spliramest(X, y, test_size = 0.20)
svc=SVC(kernel='rbf',C=20,gamma=1).fit(X_train,y_train)
y_pred = svc.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
from sklearn.metrics import mean_squared_error
rmse = np.sqrt(mean_squared_error(y_test,y_pred))
print("rmse=",rmse)
# Out:
# [[50  0]
#  [50  0]]
#               precision    recall  f1-score   support
#
#            1       0.50      1.00      0.67        50
#            4       0.00      0.00      0.00        50
#
#     accuracy                           0.50       100
#    macro avg       0.25      0.50      0.33       100
# weighted avg       0.25      0.50      0.33       100
#
# rmse= 2.1213203435596424
# C:\Users\Adhyyan\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.svm import SVC
